# %% [markdown]
# # Analysis of Twitter's Trending Topics in Comparison to Top News Headlines
# ## Zion Calvo | Surya Keswani | Donald Stewart
# ### sukeswan@ucsc.edu | dolstewa@ucsc.edu | zcalvo@ucsc.edu
#
# This notebook creates an interactive visualization of Twitter's trending topics from March 1, 2011 to March 7, 2011. The dataset comes from RMIT University in Australia. The dataset can be found [here](http://nlp.uned.es/~damiano/datasets/TT-classification.html). The interactive visualization was made using Google's open-source Facets Library ([linked here](https://pair-code.github.io/facets/)). To run this notebook, download the dataset and store this notebook in the same directory as the dataset.
#
# #### Information about the Twitter Trending Topics dataframe (processed in the read_data function)
# 1. `Md5 Hash`: Each of the 1,036 trending topics has a hash assigned to it. There are 1,036 files with tweet information. Each file is titled with a Md5 hash and corresponds to the trending topic hash.
#
# 2. `Date`: Each topic is assigned the date of when it became trending. The dates in the original dataset are formatted as yyyyMMdd. The read_data function reformats the dates as Day MM/DD/YYYY.
#
# 3. `Topic`: The trending twitter topics, ranging from news stories to people to hashtags.
#
# 4. `Type`: Each of the 1,036 topics have been analyzed by RMIT and manually categorized. The manual annotation consists in one of the four classes in the taxonomy:
#
#     + news
#     + ongoing-event
#     + meme
#     + commemorative
#
#
# 5. `Tweets`: The number of times a topic was tweeted about during the dataset collection period. The number of tweets have been extracted from the tweets folder, looking at the corresponding Md5 hash file for each topic.
# 6. `Unique Users`: The number of unique users that tweeted about the corresponding trending topic during the dataset collection period. The unique users have been extracted from the tweets folder, looking at the corresponding Md5 hash file for each topic.
# 7. `Average Traffic`: The average of the # Tweets and Unique Users. This score serves as another way to measure the growing trends.
#
# #### Functions
# 1. `read_data()`: Takes the data in the directory and converts it to a pandas dataframe.
# 2. `read_headlines()`: Reads in the top 35 headlines in provided headlines file. Headlines have been webscrapped from top news sources. Headlines stored in pandas dataframe.
# 3. `get_topX()`: Uses ttt dataframe and X integer as input and outputs 3 dataframes
#
#     + `topX_avg`: Dataframe with the top X topics based on highest average traffic score
#     + `topX_users`: Dataframe with the top X topics based on highest number of unique users
#     + `topX_tweets`: Dataframe with the top X topics based on the highest number of tweets
#
#
# 4. `run_facets()`: Takes dataframe as input and return interactive data visualization tool
# 5. `get_tweets()`: *Coming soon*
# 6. `main()`: Makes function calls and prints data analysis to console. To see full output, change the `main()` cell settings by clicking *Cell -> Cell Output -> Toggle Scrolling*
#
# ***Note***: In order to respect Twitter's TOS, tweets are not redistributed and only tweets ids and author screen names are provided. Tweet texts can be downloaded using scripts.
#
# ***Note***: The Facet library visualization takes 30-60 seconds to load.

# %%
import pandas as pd                                                             
import io        
# !pip`` install facets-overview                                                    
from IPython.core.display import display, HTML                                  
print("Imports completed")
# Out:
# Collecting facets-overview
#   Downloading https://files.pythonhosted.org/packages/df/8a/0042de5450dbd9e7e0773de93fe84c999b5b078b1f60b4c19ac76b5dd889/facets_overview-1.0.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.16.0 in /opt/anaconda3/lib/python3.7/site-packages (from facets-overview) (1.17.2)
# Requirement already satisfied: pandas>=0.22.0 in /opt/anaconda3/lib/python3.7/site-packages (from facets-overview) (0.25.1)
# Requirement already satisfied: protobuf>=3.7.0 in /opt/anaconda3/lib/python3.7/site-packages (from facets-overview) (3.11.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.22.0->facets-overview) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.22.0->facets-overview) (2019.3)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.7.0->facets-overview) (1.12.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.7.0->facets-overview) (41.4.0)
# Installing collected packages: facets-overview
# Successfully installed facets-overview-1.0.0
# Imports completed

# %%
def read_data(): #read data and store in ttt dataframe
    # pandas reads uploaded csv file and stores in twitter trending topics dataframe
    fields = ["Md5 Hash", "Date", "Topic", "Type"];
    ttt = pd.read_csv('TT-annotations.csv', sep=";", header=None, names=fields)
    hashList = ttt["Md5 Hash"].tolist()
    amount_tweets = []
    unique_users = []
    
    for file in hashList:
        hash_file = pd.read_csv("tweets/" + file, sep="\t", header=None, names=["Tweet ID", "User", "MD5 Hash"])
        amount_tweets.append(len(hash_file))
        unique_users.append(len(list(hash_file.User.unique())))
    
    # convert the date formats to be more readable
    ttt['Date'].replace({20110301: "Tuesday 3/1/11", 
                         20110302: "Wednesday 3/2/11",
                         20110303: "Thursday 3/3/11", 
                         20110304: "Friday 3/4/11", 
                         20110305: "Saturday 3/5/11",
                         20110306: "Sunday 3/6/11", 
                         20110307: "Monday 3/7/11"}, inplace = True)
    
    # add the unique number of tweets and unique users per topic in the trending list 
    ttt['# Tweets'] = amount_tweets
    ttt['Unique Users'] = unique_users
    ttt['Average Traffic'] = (ttt['# Tweets'] + ttt['Unique Users'])/2
    return ttt                                                                   # dataframe preview

# %%
def read_headlines(): 
    headlines = pd.read_csv('headline - Sheet1.csv')
    
    # convert the date formats to be more readable
    headlines['Date'].replace({20110301: "Tuesday 3/1/11", 
                               20110302: "Wednesday 3/2/11",
                               20110303: "Thursday 3/3/11", 
                               20110304: "Friday 3/4/11", 
                               20110305: "Saturday 3/5/11",
                               20110306: "Sunday 3/6/11", 
                               20110307: "Monday 3/7/11"}, inplace = True)
    return headlines

# %%
def get_topX(ttt, X): # returns the top 30 topics based on avg traffic, users, and # of tweets, each stored in a dataframe
    topX_avg = ttt.nlargest(X, ['Average Traffic']) 
    topX_users = ttt.nlargest(X, ['Unique Users'])
    topX_tweets = ttt.nlargest(X, ['# Tweets'])
    return topX_avg, topX_users, topX_tweets

# %%
def run_facets(dataframe):
    jsonstr = dataframe.to_json(orient='records')   # Display the Dive visualization for the data
    HTML_TEMPLATE = """
            <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
            <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
            <facets-dive id="elem" height="600"></facets-dive>
            <script>
              var data = {jsonstr};
              document.querySelector("#elem").data = data;
            </script>"""
    html = HTML_TEMPLATE.format(jsonstr=jsonstr)    # Note: This code block has been taken from Google facets tutorial 
    display(HTML(html))                             # Link to tutorial: https://colab.research.google.com/github/PAIR-code/facets/blob/master/colab_facets.ipynb#scrollTo=blPpZw5R3Bb4

# %%
def get_tweets():
    from requests import get
    from bs4 import BeautifulSoup as bs4

    main_page = get('https://twitter.com/anyuser/status/44004278418939904')
    page_html = bs4(main_page.text, 'html.parser')
    page_html.find('title').text

# %%
def main():
    ttt = read_data()
    #headlines = read_headlines()
    topX_avg, topX_users, topX_tweets = get_topX(ttt, 35)

    print("Interactive Facets Visulization Below:")
    run_facets(ttt)

    print("TTT Dataframe Preveiw Below:")
    display(ttt)

    print("Top 35 Trending Topics based on Average Traffic Below:")
    display(topX_avg)

    print("Top 35 Trending Topics based on Unique Users Below:")
    display(topX_users)

    print("Top 35 Trending Topics based on # of Tweets Below:")
    display(topX_tweets)
    
    # print("Top 35 News Headlines Below:")
    # display(headlines)

# %%
main()
# Out:
# Interactive Facets Visulization Below:
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#             <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#             <facets-dive id="elem" height="600"></facets-dive>
#             <script>
#               var data = [{"Md5 Hash":"e86dba234c7429d9aea70c5f104dbebc","Date":"Sunday 3\/6\/11","Topic":"#mileyonsnl","Type":"ongoing-event","# Tweets":1358,"Unique Users":536,"Average Traffic":947.0},{"Md5 Hash":"fe2dca2bdfca21e6c83567a531d6534e","Date":"Sunday 3\/6\/11","Topic":"Leap Year","Type":"ongoing-event","# Tweets":1496,"Unique Users":1335,"Average Traffic":1415.5},{"Md5 Hash":"cf90d03111f55e55ff9c7b5ef079fa30","Date":"Saturday 3\/5\/11","Topic":"Sober Valley Lodge","Type":"meme","# Tweets":1490,"Unique Users":1376,"Average Traffic":1433.0},{"Md5 Hash":"748089790952e9dbfb174b7ef39adf2b","Date":"Thursday 3\/3\/11","Topic":"Howard Davies","Type":"news","# Tweets":557,"Unique Users":452,"Average Traffic":504.5},{"Md5 Hash":"3b7dd11b6654dd5f35745285ededdbd9","Date":"Thursday 3\/3\/11","Topic":"Sky News","Type":"news","# Tweets":1483,"Unique Users":1203,"Average Traffic":1343.0},{"Md5 Hash":"16d9b6e9aa11a199a23566fb23fa4106","Date":"Friday 3\/4\/11","Topic":"Velez","Type":"ongoing-event","# Tweets":1320,"Unique Users":848,"Average Traffic":1084.0},{"Md5 Hash":"482cad8725e1cd468e108a11376c324c","Date":"Sunday 3\/6\/11","Topic":"Morkel","Type":"ongoing-event","# Tweets":901,"Unique Users":632,"Average Traffic":766.5},{"Md5 Hash":"f24caf7a04ab962804d9f81c1d6cccb9","Date":"Monday 3\/7\/11","Topic":"Brazil\u2665LadyGaga","Type":"meme","# Tweets":1307,"Unique Users":313,"Average Traffic":810.0},{"Md5 Hash":"2c2a88c024e8e3f65a54e07edd9f5394","Date":"Monday 3\/7\/11","Topic":"#dealwithit","Type":"meme","# Tweets":1369,"Unique Users":772,"Average Traffic":1070.5},{"Md5 Hash":"6da1c97714473a36b5da501815b21fc4","Date":"Tuesday 3\/1\/11","Topic":"Ban Jordan Heels","Type":"meme","# Tweets":235,"Unique Users":234,"Average Traffic":234.5},{"Md5 Hash":"e8611c0126305e7a3af7ebe8317dc699","Date":"Tuesday 3\/1\/11","Topic":"RIP Jane Russell","Type":"news","# Tweets":1497,"Unique Users":1441,"Average Traffic":1469.0},{"Md5 Hash":"e0836fb589d880e3bfd06a9b2065d0c0","Date":"Thursday 3\/3\/11","Topic":"Helau","Type":"commemorative","# Tweets":1046,"Unique Users":853,"Average Traffic":949.5},{"Md5 Hash":"2a5d19e345b324d5ecfa0d8314dce0fd","Date":"Monday 3\/7\/11","Topic":"Sargento Pimenta","Type":"ongoing-event","# Tweets":1496,"Unique Users":1057,"Average Traffic":1276.5},{"Md5 Hash":"4036303a165c0d05ce47f50d90da887f","Date":"Wednesday 3\/2\/11","Topic":"Iwata","Type":"ongoing-event","# Tweets":1489,"Unique Users":1035,"Average Traffic":1262.0},{"Md5 Hash":"bc73552adb37da9c3174a0ce5a281367","Date":"Thursday 3\/3\/11","Topic":"Martha Kent","Type":"news","# Tweets":209,"Unique Users":189,"Average Traffic":199.0},{"Md5 Hash":"45d3c04cfda32e228eb9048a8bc43524","Date":"Sunday 3\/6\/11","Topic":"#suarez","Type":"ongoing-event","# Tweets":680,"Unique Users":618,"Average Traffic":649.0},{"Md5 Hash":"003e36ddeff1e5e0781580761d0c949c","Date":"Wednesday 3\/2\/11","Topic":"Zandvoort","Type":"ongoing-event","# Tweets":1490,"Unique Users":977,"Average Traffic":1233.5},{"Md5 Hash":"5eb9dc77102c157dbe36515f5be70ce7","Date":"Saturday 3\/5\/11","Topic":"Sue Perkins","Type":"ongoing-event","# Tweets":424,"Unique Users":338,"Average Traffic":381.0},{"Md5 Hash":"98d681f3bba130e62c532c2b9e207190","Date":"Monday 3\/7\/11","Topic":"Curtis Stone","Type":"ongoing-event","# Tweets":926,"Unique Users":815,"Average Traffic":870.5},{"Md5 Hash":"f4e41a7e91e582875aafbd19346c8091","Date":"Wednesday 3\/2\/11","Topic":"Antonio Nunes","Type":"ongoing-event","# Tweets":1012,"Unique Users":915,"Average Traffic":963.5},{"Md5 Hash":"107530150c943610b908a4c82168133d","Date":"Thursday 3\/3\/11","Topic":"Haley Reinhart","Type":"ongoing-event","# Tweets":347,"Unique Users":309,"Average Traffic":328.0},{"Md5 Hash":"8b0fce622128e48175cc8da44e321fd5","Date":"Monday 3\/7\/11","Topic":"#dhsmemories","Type":"meme","# Tweets":1461,"Unique Users":143,"Average Traffic":802.0},{"Md5 Hash":"944dc4d8f735381b050ff508f05bd033","Date":"Sunday 3\/6\/11","Topic":"Nick Swardson","Type":"ongoing-event","# T ...
# TTT Dataframe Preveiw Below:
#                               Md5 Hash              Date               Topic  \
# 0     e86dba234c7429d9aea70c5f104dbebc     Sunday 3/6/11         #mileyonsnl
# 1     fe2dca2bdfca21e6c83567a531d6534e     Sunday 3/6/11           Leap Year
# 2     cf90d03111f55e55ff9c7b5ef079fa30   Saturday 3/5/11  Sober Valley Lodge
# 3     748089790952e9dbfb174b7ef39adf2b   Thursday 3/3/11       Howard Davies
# 4     3b7dd11b6654dd5f35745285ededdbd9   Thursday 3/3/11            Sky News
# ...                                ...               ...                 ...
# 1031  05d739a093794343728b66d5802db10b  Wednesday 3/2/11     Antonio Damasio
# 1032  8669b32af04ae65b88b38df5662545ea   Saturday 3/5/11        Sheila Mello
# 1033  4e49ec9f0f036f91a5b34278d15484f3     Friday 3/4/11              Gareca
# 1034  d93d84ae006f530cbf2b33ebf824d48e     Monday 3/7/11      Patrícia Poeta
# 1035  98d79b7652e365b4a4b260ca2bb5583d   Thursday 3/3/11                 PIB
#
#                Type  # Tweets  Unique Users  Average Traffic
# 0     ongoing-event      1358           536            947.0
# 1     ongoing-event      1496          1335           1415.5
# 2              meme      1490          1376           1433.0
# 3              news       557           452            504.5
# 4              news      1483          1203           1343.0
# ...             ...       ...           ...              ...
# 1031  ongoing-event       197           166            181.5
# 1032  ongoing-event       190           170            180.0
# 1033  ongoing-event       284           222            253.0
# 1034  ongoing-event       309           283            296.0
# 1035           news      1497          1176           1336.5
#
# [1036 rows x 7 columns]
# Top 35 Trending Topics based on Average Traffic Below:
#                               Md5 Hash              Date  \
# 607   f6c5c0ae6c636b204045d21267608be5   Saturday 3/5/11
# 711   6401813085837e9f1f8b27eae98ac4f3   Saturday 3/5/11
# 1011  5eb1c412235828a21e3767fc12ab9975     Friday 3/4/11
# 10    e8611c0126305e7a3af7ebe8317dc699    Tuesday 3/1/11
# 408   257c941753478852a2436136bc72ab61  Wednesday 3/2/11
# 324   f466ab0a8cd1f819044a225a3e2bfeaa   Thursday 3/3/11
# 460   6a5c42fc43e58b8ed67ab5da8d965c51  Wednesday 3/2/11
# 529   43a77176c021459123b4c9087be6690c  Wednesday 3/2/11
# 933   b9ce5104bf8173b0565bda046bf8116c  Wednesday 3/2/11
# 333   b4247c18124765ae6cacb49f80d5d0ab    Tuesday 3/1/11
# 1028  55584a60320a54989ef057e25836cdbe   Saturday 3/5/11
# 357   4dcf6c45da315ab121d9bcc23a157866   Thursday 3/3/11
# 877   463636c775a2ba72afdfd29d240b4a19  Wednesday 3/2/11
# 736   c80e68f4191a8150a52cf5cf43a6bdaf  Wednesday 3/2/11
# 178   e013eff7b282cdb226222534447ec040   Saturday 3/5/11
# 960   6ee8eb43943b50d0a09a7063878d3d69   Thursday 3/3/11
# 376   ef62f81fa2b448d7c6052b6ea2ecff04   Thursday 3/3/11
# 131   17aee153dd984e648d8f8d43190f7463     Monday 3/7/11
# 916   1a2529dd59176ca042a42544d47bdf33     Sunday 3/6/11
# 503   1e172aca3fdf9ebaae608256325df969     Friday 3/4/11
# 505   2e3af71d9d5ec783baca5795f7a5b432     Monday 3/7/11
# 435   6f59f47811a39e6fe6783372c52f009d    Tuesday 3/1/11
# 744   7ca28c67b72617f0992a8be7eb6a489f    Tuesday 3/1/11
# 922   54ac822e416a0c5f01d66a6ed43a34c5    Tuesday 3/1/11
# 2     cf90d03111f55e55ff9c7b5ef079fa30   Saturday 3/5/11
# 769   4f13920388d9432f6b2bde91cf03f60b     Sunday 3/6/11
# 861   dd7bde87ebef98efd6dfc5d022a90d7a     Monday 3/7/11
# 899   056279320a80cc5b1f135fad76c0d13d     Friday 3/4/11
# 422   8653223b51b6bbfdfee6d98b227bd3b0     Sunday 3/6/11
# 739   52153e6dffc71c31ced035945377e0d5     Sunday 3/6/11
# 927   949e1fd56b30093e176cb25d34544336  Wednesday 3/2/11
# 451   247f072c4b03f7416bcbf36367fdf200  Wednesday 3/2/11
# 113   ae01ebf13913be8a16e0ac5e0042ccb6  Wednesday 3/2/11
# 148   752bfa88b37405d87b55de7756d4eed8     Sunday 3/6/11
# 528   72ddba4c9c7216e945ecc0dc3d5f629e  Wednesday 3/2/11
#
#                        Topic           Type  # Tweets  Unique Users  \
# 607                  YOURMAN           meme      1492          1479
# 711             Mountain Dew           meme      1493          1454
# 1011              Fast Times  ongoing-event      1498          1441
# 10          RIP Jane Russell           news      1497          1441
# 408   TOP10 Profile STALKERS           meme      1496          1439
# 324          Google Profiles           news      1497          1435
# 460               Wild Thing  ongoing-event      1500          1429
# 529           Emilio Estevez           meme      1496          1433
# 933               Adonis DNA           meme      1493          1424
# 333             Lázaro Ramos  ongoing-event      1498          1416
# 1028          Watching Taken  ongoing-event      1483          1431
# 357             World Record           news      1475          1438
# 877              Nancy Grace           meme      1464          1445
# 736            Still Winning           meme      1462          1442
# 178        Adjustment Bureau           meme      1494          1402
# 960         Late Night Snack           meme      1493          1401
# 376             Pulp Fiction           news      1491          1395
# 131              Daniel Tosh  ongoing-event      1472          1412
# 916           Lord Voldemort           meme      1487          1395
# 503            Great Morning           meme      1476          1400
# 505            Indiana Jones  ongoing-event      1497          1379
# 435              John Stamos           news      1494          1381
# 744            Nelly Furtado           news      1487          1386
# 922             Piers Morgan  ongoing-event      1477          1394
# 2         Sober Valley Lodge           meme      1490          1376
# 769            Lakers\/Spurs  ongoing-event      1487          1379
# 861                     Lent           meme      1492          1374
# 899               Blue Shirt           meme      1499          1367
# 422            Shannon Brown  ongoing-event      1464          1401
# 739             Derita Cinta  ongoing-event      1493          1372
# 927            Fernanda Lima  ongoing-event      1486          1379
# 451             Major League           meme      1495          1367
# 113           Wendy Williams  ongoing-event      1492          1369
# 148       Congrats Liverpool  ongoing-event      1468          1393
# 528               Bernie Mac           meme      1498          1363
#
#       Average Traffic
# 607            1485.5
# 711            1473.5
# 1011           1469.5
# 10             1469.0
# 408            1467.5
# 324            1466.0
# 460            1464.5
# 529            1464.5
# 933            1458.5
# 333            1457.0
# 1028           1457.0
# 357            1456.5
# 877            1454.5
# 736            1452.0
# 178            1448.0
# 960            1447.0
# 376            1443.0
# 131            1442.0
# 916            1441.0
# 503            1438.0
# 505            1438.0
# 435            1437.5
# 744            1436.5
# 922            1435.5
# 2              1433.0
# 769            1433.0
# 861            1433.0
# 899            1433.0
# 422            1432.5
# 739            1432.5
# 927            1432.5
# 451            1431.0
# 113            1430.5
# 148            1430.5
# 528            1430.5
# Top 35 Trending Topics based on Unique Users Below:
#                               Md5 Hash              Date  \
# 607   f6c5c0ae6c636b204045d21267608be5   Saturday 3/5/11
# 711   6401813085837e9f1f8b27eae98ac4f3   Saturday 3/5/11
# 877   463636c775a2ba72afdfd29d240b4a19  Wednesday 3/2/11
# 736   c80e68f4191a8150a52cf5cf43a6bdaf  Wednesday 3/2/11
# 10    e8611c0126305e7a3af7ebe8317dc699    Tuesday 3/1/11
# 1011  5eb1c412235828a21e3767fc12ab9975     Friday 3/4/11
# 408   257c941753478852a2436136bc72ab61  Wednesday 3/2/11
# 357   4dcf6c45da315ab121d9bcc23a157866   Thursday 3/3/11
# 324   f466ab0a8cd1f819044a225a3e2bfeaa   Thursday 3/3/11
# 529   43a77176c021459123b4c9087be6690c  Wednesday 3/2/11
# 1028  55584a60320a54989ef057e25836cdbe   Saturday 3/5/11
# 460   6a5c42fc43e58b8ed67ab5da8d965c51  Wednesday 3/2/11
# 933   b9ce5104bf8173b0565bda046bf8116c  Wednesday 3/2/11
# 333   b4247c18124765ae6cacb49f80d5d0ab    Tuesday 3/1/11
# 131   17aee153dd984e648d8f8d43190f7463     Monday 3/7/11
# 178   e013eff7b282cdb226222534447ec040   Saturday 3/5/11
# 422   8653223b51b6bbfdfee6d98b227bd3b0     Sunday 3/6/11
# 960   6ee8eb43943b50d0a09a7063878d3d69   Thursday 3/3/11
# 503   1e172aca3fdf9ebaae608256325df969     Friday 3/4/11
# 101   f2d205904b535469e2c4b82e5df538c0     Monday 3/7/11
# 52    2d17c1d3a6d90056244caae9277c4639     Sunday 3/6/11
# 365   84d7d7cb407bf616f8466e7c8a03265e  Wednesday 3/2/11
# 376   ef62f81fa2b448d7c6052b6ea2ecff04   Thursday 3/3/11
# 916   1a2529dd59176ca042a42544d47bdf33     Sunday 3/6/11
# 922   54ac822e416a0c5f01d66a6ed43a34c5    Tuesday 3/1/11
# 148   752bfa88b37405d87b55de7756d4eed8     Sunday 3/6/11
# 978   fa9e0e6c74565adda24b7bd0db662da0     Friday 3/4/11
# 744   7ca28c67b72617f0992a8be7eb6a489f    Tuesday 3/1/11
# 435   6f59f47811a39e6fe6783372c52f009d    Tuesday 3/1/11
# 505   2e3af71d9d5ec783baca5795f7a5b432     Monday 3/7/11
# 769   4f13920388d9432f6b2bde91cf03f60b     Sunday 3/6/11
# 927   949e1fd56b30093e176cb25d34544336  Wednesday 3/2/11
# 480   fe42f1ba84557e41c9e2360e0991164e     Sunday 3/6/11
# 2     cf90d03111f55e55ff9c7b5ef079fa30   Saturday 3/5/11
# 447   cd2952429b323470d53aa5102e083dba     Friday 3/4/11
#
#                        Topic           Type  # Tweets  Unique Users  \
# 607                  YOURMAN           meme      1492          1479
# 711             Mountain Dew           meme      1493          1454
# 877              Nancy Grace           meme      1464          1445
# 736            Still Winning           meme      1462          1442
# 10          RIP Jane Russell           news      1497          1441
# 1011              Fast Times  ongoing-event      1498          1441
# 408   TOP10 Profile STALKERS           meme      1496          1439
# 357             World Record           news      1475          1438
# 324          Google Profiles           news      1497          1435
# 529           Emilio Estevez           meme      1496          1433
# 1028          Watching Taken  ongoing-event      1483          1431
# 460               Wild Thing  ongoing-event      1500          1429
# 933               Adonis DNA           meme      1493          1424
# 333             Lázaro Ramos  ongoing-event      1498          1416
# 131              Daniel Tosh  ongoing-event      1472          1412
# 178        Adjustment Bureau           meme      1494          1402
# 422            Shannon Brown  ongoing-event      1464          1401
# 960         Late Night Snack           meme      1493          1401
# 503            Great Morning           meme      1476          1400
# 101              Warner Bros           news      1445          1398
# 52         Always Say Always  ongoing-event      1462          1396
# 365                  #winner           meme      1433          1396
# 376             Pulp Fiction           news      1491          1395
# 916           Lord Voldemort           meme      1487          1395
# 922             Piers Morgan  ongoing-event      1477          1394
# 148       Congrats Liverpool  ongoing-event      1468          1393
# 978              Hala Madrid           news      1473          1387
# 744            Nelly Furtado           news      1487          1386
# 435              John Stamos           news      1494          1381
# 505            Indiana Jones  ongoing-event      1497          1379
# 769            Lakers\/Spurs  ongoing-event      1487          1379
# 927            Fernanda Lima  ongoing-event      1486          1379
# 480    Charlie Sheen Ustream  ongoing-event      1464          1378
# 2         Sober Valley Lodge           meme      1490          1376
# 447                  Rev Run  ongoing-event      1484          1375
#
#       Average Traffic
# 607            1485.5
# 711            1473.5
# 877            1454.5
# 736            1452.0
# 10             1469.0
# 1011           1469.5
# 408            1467.5
# 357            1456.5
# 324            1466.0
# 529            1464.5
# 1028           1457.0
# 460            1464.5
# 933            1458.5
# 333            1457.0
# 131            1442.0
# 178            1448.0
# 422            1432.5
# 960            1447.0
# 503            1438.0
# 101            1421.5
# 52             1429.0
# 365            1414.5
# 376            1443.0
# 916            1441.0
# 922            1435.5
# 148            1430.5
# 978            1430.0
# 744            1436.5
# 435            1437.5
# 505            1438.0
# 769            1433.0
# 927            1432.5
# 480            1421.0
# 2              1433.0
# 447            1429.5
# Top 35 Trending Topics based on # of Tweets Below:
#                               Md5 Hash              Date                Topic  \
# 70    050feefcdd7d85023c61753474848a48     Monday 3/7/11          Rosenmontag
# 114   4a4de7aa4553a1bd4fea73042d479f6b    Tuesday 3/1/11        Robot Chicken
# 460   6a5c42fc43e58b8ed67ab5da8d965c51  Wednesday 3/2/11           Wild Thing
# 602   6de9a283570262f6978fdbbab2c5bc41  Wednesday 3/2/11                Kalla
# 809   9ff084e11fff0932581f87e9a5e19c1a   Thursday 3/3/11  Wellington Paulista
# 134   9b5ff8a3f9652462677d4ffe8dbc5a67     Friday 3/4/11   Java Jazz Festival
# 300   028cd4c37ed3a705a309424766cccb5e    Tuesday 3/1/11       Carlos Estevez
# 353   1c6d0fdb4b97bf152dd965d516873a45   Thursday 3/3/11          Nick Carter
# 596   86007de4b13059d7af68019129b25d54   Saturday 3/5/11               Destra
# 716   20eb10b2a243bb876e3db547bdfd3e8f     Friday 3/4/11          Taylor Hall
# 735   733e623fca27e53a68d831c04a668f42    Tuesday 3/1/11                 CHUM
# 853   2088afa84c6fe3025122308db9a0b57e     Monday 3/7/11         Kobalt Tools
# 899   056279320a80cc5b1f135fad76c0d13d     Friday 3/4/11           Blue Shirt
# 921   257c0111c5eb728d827d91b8c73d3e9b  Wednesday 3/2/11              Lil Jon
# 253   dc81952301ed30d02d49b9ba00bd74f3     Monday 3/7/11       Mumford & Sons
# 333   b4247c18124765ae6cacb49f80d5d0ab    Tuesday 3/1/11         Lázaro Ramos
# 528   72ddba4c9c7216e945ecc0dc3d5f629e  Wednesday 3/2/11           Bernie Mac
# 755   877890e06827716cea520cae6c2b24c9    Tuesday 3/1/11              Grenzen
# 843   6596fe811358a7e13de908368079e30b    Tuesday 3/1/11            Gift Raps
# 849   c98f72390cc35be838ec6ad160e73496    Tuesday 3/1/11       Chelsea Lately
# 992   1406dad51b322f589da21c9cdd536936   Thursday 3/3/11           Balenciaga
# 1011  5eb1c412235828a21e3767fc12ab9975     Friday 3/4/11           Fast Times
# 10    e8611c0126305e7a3af7ebe8317dc699    Tuesday 3/1/11     RIP Jane Russell
# 47    6d03fafccc6e231a3465246525f690be   Saturday 3/5/11         Pérola Negra
# 56    4b7da4edf137ebf2603ddae88feb6b09     Monday 3/7/11     Alejandra Guzman
# 81    b19841e8995751d310de279f43c8c56a     Monday 3/7/11              Pac Div
# 162   fc28b52ecac9112ed5a716638af66cd0  Wednesday 3/2/11               Cusack
# 218   7d117c7d210bc817fb5fb4b24b472a05  Wednesday 3/2/11     Marsha Ambrosius
# 307   6e255f75b4d8cfed4bd5af7ff4c0b408     Sunday 3/6/11            Wes Brown
# 309   d79d24d86bf33bf46d3c106133a2d24b   Saturday 3/5/11          Bear Grylls
# 324   f466ab0a8cd1f819044a225a3e2bfeaa   Thursday 3/3/11      Google Profiles
# 335   25a41b23594c5c55efc070b07f679faa     Monday 3/7/11           Ocho Cinco
# 485   4a4e2ab094a4521b06252e9fdaf1fd0a     Monday 3/7/11          Bobby Brown
# 505   2e3af71d9d5ec783baca5795f7a5b432     Monday 3/7/11        Indiana Jones
# 551   83e666a525ab1a77f0c764bee7a4ea33     Monday 3/7/11                Tonka
#
#                Type  # Tweets  Unique Users  Average Traffic
# 70             meme      1500          1298           1399.0
# 114   ongoing-event      1500          1279           1389.5
# 460   ongoing-event      1500          1429           1464.5
# 602            news      1500          1203           1351.5
# 809   ongoing-event      1500           987           1243.5
# 134   ongoing-event      1499          1305           1402.0
# 300            meme      1499          1324           1411.5
# 353   ongoing-event      1499          1150           1324.5
# 596   ongoing-event      1499          1133           1316.0
# 716            news      1499          1164           1331.5
# 735   ongoing-event      1499          1113           1306.0
# 853            news      1499           828           1163.5
# 899            meme      1499          1367           1433.0
# 921   ongoing-event      1499          1309           1404.0
# 253            meme      1498          1327           1412.5
# 333   ongoing-event      1498          1416           1457.0
# 528            meme      1498          1363           1430.5
# 755            news      1498          1295           1396.5
# 843            meme      1498          1127           1312.5
# 849   ongoing-event      1498          1330           1414.0
# 992            news      1498          1195           1346.5
# 1011  ongoing-event      1498          1441           1469.5
# 10             news      1497          1441           1469.0
# 47    ongoing-event      1497          1086           1291.5
# 56    ongoing-event      1497          1314           1405.5
# 81             meme      1497          1159           1328.0
# 162   ongoing-event      1497          1022           1259.5
# 218            news      1497          1285           1391.0
# 307   ongoing-event      1497          1306           1401.5
# 309   ongoing-event      1497          1317           1407.0
# 324            news      1497          1435           1466.0
# 335            meme      1497          1355           1426.0
# 485   ongoing-event      1497          1311           1404.0
# 505   ongoing-event      1497          1379           1438.0
# 551   ongoing-event      1497          1229           1363.0
